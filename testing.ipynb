# %%
from src.data_providers.yfinance_provider import YFinanceProvider
import logging
logger = logging.getLogger(__name__)

# %%
yf = YFinanceProvider()

# %%
tickers = ['VTI', 'BND']
start_date = '2014-06-15'
end_date = '2023-12-31'
ohlcv = yf.fetch_ohlcv(tickers, start_date, end_date)

# %%
print(ohlcv.head())
# Out:
# Ticker            VTI                                                  BND  \
# Price            Open       High        Low      Close   Volume       Open
# Date
# 2014-06-16  82.620797  82.982702  82.505647  82.826424  2778000  59.139240
# 2014-06-17  82.711282  83.237686  82.629033  83.122536  1089700  59.081421
# 2014-06-18  83.138992  83.764092  82.966266  83.739418  1326200  59.074164
# 2014-06-19  83.813453  83.895702  83.509123  83.838127  2130700  59.254917
# 2014-06-20  84.060197  84.060197  83.879250  84.035522  1952800  59.066938
#
# Ticker
# Price            High        Low      Close   Volume
# Date
# 2014-06-16  59.189847  59.110320  59.146465  3534000
# 2014-06-17  59.095878  59.009125  59.009125   612900
# 2014-06-18  59.175380  59.038019  59.160923  1495900
# 2014-06-19  59.262149  59.059717  59.110325  3345400
# 2014-06-20  59.153697  59.066938  59.146465  2863700
